# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Importing required libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Treatment and Data Analysis

# %%
df=pd.read_excel("ANZ synthesised transaction dataset.xlsx")

# %%
df.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# ...

# %%
df.shape
# Out:
# (12043, 23)

# %%
df.dtypes
# Out:
# status                       object
# card_present_flag           float64
# bpay_biller_code             object
# account                      object
# currency                     object
# long_lat                     object
# txn_description              object
# merchant_id                  object
# merchant_code               float64
# first_name                   object
# balance                     float64
# date                 datetime64[ns]
# gender                       object
# age                           int64
# merchant_suburb              object
# merchant_state               object
# extraction                   object
# amount                      float64
# transaction_id               object
# country                      object
# customer_id                  object
# merchant_long_lat            object
# movement                     object
# dtype: object

# %%
#checking for null values
df.isnull().sum()
# Out:
# status                   0
# card_present_flag     4326
# bpay_biller_code     11158
# account                  0
# currency                 0
# long_lat                 0
# txn_description          0
# merchant_id           4326
# merchant_code        11160
# first_name               0
# balance                  0
# date                     0
# gender                   0
# age                      0
# merchant_suburb       4326
# merchant_state        4326
# extraction               0
# amount                   0
# transaction_id           0
# country                  0
# customer_id              0
# merchant_long_lat     4326
# movement                 0
# dtype: int64

# %%
df.nunique()
# Out:
# status                   2
# card_present_flag        2
# bpay_biller_code         3
# account                100
# currency                 1
# long_lat               100
# txn_description          6
# merchant_id           5725
# merchant_code            1
# first_name              80
# balance              12006
# date                    91
# gender                   2
# age                     33
# merchant_suburb       1609
# merchant_state           8
# extraction            9442
# amount                4457
# transaction_id       12043
# country                  1
# customer_id            100
# merchant_long_lat     2703
# movement                 2
# dtype: int64

# %%
#dropping unneeded columns that doesnt have variance and high null vlaues

new_df= df.drop(['country','currency','merchant_code','bpay_biller_code'],axis=1)

# %%
new_df.head()
# Out:
#        status  card_present_flag         account       long_lat  \
# 0  authorized                1.0  ACC-1598451071  153.41 -27.95
# 1  authorized                0.0  ACC-1598451071  153.41 -27.95
# 2  authorized                1.0  ACC-1222300524  151.23 -33.94
# 3  authorized                1.0  ACC-1037050564  153.10 -27.66
# 4  authorized                1.0  ACC-1598451071  153.41 -27.95
#
#   txn_description                           merchant_id first_name  balance  \
# 0             POS  81c48296-73be-44a7-befa-d053f48ce7cd      Diana    35.39
# 1       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e      Diana    21.20
# 2             POS  835c231d-8cdf-4e96-859d-e9d571760cf0    Michael     5.71
# 3       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673     Rhonda  2117.22
# 4       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0      Diana    17.95
#
#         date gender  age merchant_suburb merchant_state  \
# 0 2018-08-01      F   26         Ashmore            QLD
# ...

# %%
df.describe()
# Out:
#        card_present_flag  merchant_code        balance           age  \
# count        7717.000000          883.0   12043.000000  12043.000000
# mean            0.802644            0.0   14704.195553     30.582330
# std             0.398029            0.0   31503.722652     10.046343
# min             0.000000            0.0       0.240000     18.000000
# 25%             1.000000            0.0    3158.585000     22.000000
# 50%             1.000000            0.0    6432.010000     28.000000
# 75%             1.000000            0.0   12465.945000     38.000000
# max             1.000000            0.0  267128.520000     78.000000
#
#              amount
# count  12043.000000
# mean     187.933588
# std      592.599934
# min        0.100000
# 25%       16.000000
# 50%       29.000000
# 75%       53.655000
# max     8835.980000

# %% [markdown]
# ### Are there any data issues? Does the data need to be cleaned?
#  yes there are null values and columns with no relevance these null value has to be treateed

# %% [markdown]
# ### Finding average transaction amount and average transactions each month

# %%
avg=df['amount'].mean()
print("averge transaction amount is",avg)
# Out:
# averge transaction amount is 187.93358797641767

# %%
#average each month
import datetime
df.groupby(df['date'].dt.strftime('%B'))['amount'].mean().sort_values()
# Out:
# date
# September    182.045903
# August       185.121867
# October      196.427323
# Name: amount, dtype: float64

# %% [markdown]
# # Visulaisation of data

# %% [markdown]
# #### Segment the dataset by transaction date and time. Visualise transaction volume and spending over the course of an average day or week

# %%
df.groupby(df['date'].dt.strftime('%W'))['amount'].mean().plot(kind='bar')
plt.xlabel("week",fontsize=12)
plt.ylabel("Average Transcation amount",fontsize=12)
plt.show()

# %% [markdown]
# #### For a challenge – what insights can you draw from the location information provided in the dataset?

# %%
df.groupby(df['merchant_state'])['amount'].mean().plot(kind='bar')
plt.ylabel("transaction amount")
plt.xlabel("mechant state")
plt.show()

# %%
#box and distplot for age
fig,ax=plt.subplots(1,2,figsize=(10,8))

sns.boxplot(df['age'],ax=ax[0],orient='v')

sns.distplot(df['age'],ax=ax[1])
plt.show()

# %%
#box and distplot for amount
fig,ax=plt.subplots(1,2,figsize=(10,8))

sns.boxplot(df['amount'],ax=ax[0],orient='v')

sns.distplot(df['amount'],ax=ax[1])
plt.show()

# %%
#box and distplot for balance
fig,ax=plt.subplots(1,2,figsize=(10,8))

sns.boxplot(df['balance'],ax=ax[0],orient='v')

sns.distplot(df['balance'],ax=ax[1])
plt.show()

# %%
#pairplot to understand relationsips
sns.pairplot(new_df)
plt.show()
